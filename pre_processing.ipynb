# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/BRA-modified.csv")

# %% [markdown]
# # 1 - Análise descritiva dos atributos

# %% [markdown]
# ## a) Descrição dos atributos

# %% [markdown]
# | Atributo | Tipo do Atributo | Descrição do Atributo |
# |----------|------------------|------------------------|
# | Seasons  | Categórico nominal         | Indica a temporada da partida |
# | Home     | Categórico nominal | ID único para o time mandante |
# | Away     | Categórico nominal | ID único para o time visitante |
# | HG       | Discreto         | Quantidade de gols do time mandante |
# | AG       | Discreto         | Quantidade de gols do time visitante |
# | Res      | Categórico nominal | Resultado da partida |
# | PSCH     | Contínuo         | Odd de vitória do time mandante na Pinnacle Sports |
# | PSCD     | Contínuo         | Odd de empate na Pinnacle Sports |
# | PSCA     | Contínuo         | Odd de vitória do time visitante na Pinnacle Sports |
# | MaxCH    | Contínuo         | Odd máxima de vitória do time mandante no mercado |
# | MaxCD    | Contínuo         | Odd máxima de empate no mercado |
# | MaxCA    | Contínuo         | Odd máxima de vitória do time visitante no mercado |
# | AvgCH    | Contínuo         | Valor médio das odds para vitória do time mandante |
# | AvgCD    | Contínuo         | Valor médio das odds para empate |
# | AvgCA    | Contínuo         | Valor médio das odds para vitória do time visitante |
# | W_H      | Discreto         | Partidas vencidas pelo mandante antes da partida atual |
# | D_H      | Discreto         | Partidas empatadas pelo mandante antes da partida atual |
# | L_H      | Discreto         | Partidas perdidas pelo mandante antes da partida atual |
# | GF_H     | Discreto         | Gols marcados pelo mandante antes da partida atual |
# | GA_H     | Discreto         | Gols sofridos pelo mandante antes da partida atual |
# | GD_H     | Discreto         | Diferença de gols do mandante antes da partida atual |
# | W_A      | Discreto         | Partidas vencidas pelo visitante antes da partida atual |
# | D_A      | Discreto         | Partidas empatadas pelo visitante antes da partida atual |
# | L_A      | Discreto         | Partidas perdidas pelo visitante antes da partida atual |
# | GF_A     | Discreto         | Gols marcados pelo visitante antes da partida atual |
# | GA_A     | Discreto         | Gols sofridos pelo visitante antes da partida atual |
# | GD_A     | Discreto         | Diferença de gols do visitante antes da partida atual |

# %% [markdown]
# ## b) Descrição e visualização dos dados

# %%
categorical_data = ["Season", "Home", "Away", "Res"]
numerical_df = df.drop(categorical_data, axis=1)
numerical_df.describe()
# Out:
#                 HG           AG         PSCH         PSCD         PSCA  \
# count  5038.000000  5038.000000  5038.000000  5038.000000  5038.000000
# mean      1.413458     0.959706     2.308543     3.637588     4.673501
# std       1.156399     0.977087     0.948401     0.651977     2.462170
# min       0.000000     0.000000     1.080000     2.540000     1.150000
# 25%       1.000000     0.000000     1.700000     3.250000     2.990000
# 50%       1.000000     1.000000     2.080000     3.450000     4.030000
# 75%       2.000000     1.750000     2.620000     3.840000     5.700000
# max       7.000000     6.000000    17.680000    12.250000    29.580000
#
#              MaxCH        MaxCD        MaxCA        AvgCH        AvgCD  \
# count  5039.000000  5039.000000  5039.000000  5039.000000  5039.000000
# mean      2.388297     3.743513     4.915922     2.234969     3.485434
# std       1.049756     0.678713     2.727218     0.883547     0.570164
# min       1.090000     2.630000     0.000000     1.070000     2.510000
# 25%       1.750000     3.330000     3.060000     1.670000     3.150000
# 50%       2.150000     3.530000     4.160000     2.030000     3.300000
# 75%       2.700000     3.950000     6.000000     2.535000     3.660000
# max      29.000000    12.500000    36.000000    20.230000    10.820000
#
#              AvgCA          W_H          D_H          L_H         GF_H  \
# count  5039.000000  5039.000000  5039.000000  5039.000000  5039.000000
# mean      4.328321     6.559238     4.994642     6.668783    21.492161
# std       2.124050     4.866174     3.484465     4.880025    14.556930
# min       1.150000     0.000000     0.000000     0.000000     0.000000
# 25%       2.860000     3.000000     2.000000     3.000000     9.000000
# 50%       3.760000     6.000000     5.000000     6.000000    20.000000
# 75%       5.280000    10.000000     7.000000    10.000000    32.000000
# max      26.580000    27.000000    17.000000    28.000000    80.000000
#
#               GA_H         GD_H          W_A          D_A          L_A  \
# count  5039.000000  5039.000000  5039.000000  5039.000000  5039.000000
# mean     21.707482    -0.215321     6.669379     4.983330     6.572733
# std      14.386838    10.060016     4.874144     3.481323     4.874142
# min       0.000000   -58.000000     0.000000     0.000000     0.000000
# 25%      10.000000    -5.000000     3.000000     2.000000     2.500000
# 50%      20.000000     0.000000     6.000000     5.000000     6.000000
# 75%      32.000000     5.000000    10.000000     7.000000    10.000000
# max      79.000000    48.000000    28.000000    17.000000    27.000000
#
#               GF_A         GA_A         GD_A
# count  5039.000000  5039.000000  5039.000000
# mean     21.705894    21.506450     0.199444
# std      14.576788    14.373081    10.091253
# min       0.000000     0.000000   -56.000000
# 25%       9.000000     9.000000    -5.000000
# 50%      20.000000    20.000000     0.000000
# 75%      32.000000    32.000000     5.000000
# max      86.000000    80.000000    53.000000

# %%
fig, axes = plt.subplots(12, 2, figsize=(12, 24)) 
axes = axes.flatten() 

for i, attribute in enumerate(numerical_df):
    axes[i].boxplot(df[attribute].dropna(), orientation='horizontal')
    axes[i].set_title(attribute)

plt.tight_layout()
plt.show()

# %% [markdown]
# Percebemos que todos os dados que representam odds e os dados que representam saldo de gols (GD - goals difference) apresentam uma grande quantidade de outliers.

# %% [markdown]
# ## c) Valores possíveis para atributos nominais e suas distribuições de probabilidades

# %%
for attribute in categorical_data:
    print(f"{df[attribute].value_counts(normalize=True)}")
    print("\n")
# Out:
# Season
# 2012    0.075412
# 2013    0.075412
# 2014    0.075412
# 2015    0.075412
# 2016    0.075412
# 2017    0.075412
# 2018    0.075412
# 2019    0.075412
# 2020    0.075412
# 2021    0.075412
# 2022    0.075412
# 2023    0.075412
# 2024    0.075412
# 2025    0.019647
# Name: proportion, dtype: float64
#
#
# Home
# 33    0.050208
# 18    0.050010
# 17    0.050010
# 11    0.050010
# 3     0.050010
# 21    0.046438
# 27    0.046239
# 22    0.046041
# 32    0.046041
# 1     0.045247
# 6     0.042270
# 14    0.038698
# 5     0.038698
# 35    0.034928
# 12    0.033935
# 34    0.031157
# 20    0.026394
# 10    0.026394
# 19    0.023616
# 36    0.023616
# 2     0.022624
# 7     0.020044
# 9     0.019845
# 29    0.018853
# 0     0.018853
# 15    0.015082
# 4     0.015082
# 16    0.015082
# 24    0.012304
# 13    0.011312
# 26    0.007541
# 30    0.007541
# 8     0.003771
# 28    0.003771
# 31    0.003771
# 23    0.003771
# 25    0.000794
# Name: proportion, dtype: float64
#
#
# Away
# 18    0.050010
# 17    0.050010
# 3     0.050010
# 11    0.050010
# 33    0.049811
# 22    0.046438
# 32    0.046438
# 27    0.046239
# 21    0.046041
# 1     0.045247
# 6     0.042469
# 14    0.038698
# 5     0.038698
# 35    0.034928
# 12    0.033935
# 34    0.031157
# 10    0.026394
# 20    0.026394
# 36    0.023616
# 19    0.023616
# 2     0.022624
# 7     0.019647
# 9     0.019647
# 29    0.018853
# 0     0.018853
# 4     0.015082
# 15    0.015082
# 16    0.015082
# 24    0.012304
# 13    0.011312
# 30    0.007541
# 26    0.007541
# 8     0.003771
# 28    0.003771
# 31    0.003771
# 23    0.003771
# 25    0.001191
# Name: proportion, dtype: float64
#
#
# Res
# H    0.484716
# D    0.269750
# A    0.245534
# Name: proportion, dtype: float64

# %% [markdown]
# ## d) Identificação de valores ausentes, aberrantes e inconsistentes
# O dataset, antes de passar por este notebook é pré-processasdo no arquivo [format_dataset.ipynb](./format_dataset.ipynb), onde algumas colunas são removidas devido à grande quantidade de valores nulos e pela grande dificuldade que seria para gerar novos valores, uma vez que a quantidade de linhas não nulas são muito baixas. Essas colunas são: "BFECH", "BFECD", "BFECA".

# %%
def check_null_itens(df):
    for index, value in df.isnull().any().items():    
        if value:
            print(f"{index} contains {df[index].isnull().sum()} null values")

check_null_itens(df)
# Out:
# HG contains 1 null values
# AG contains 1 null values
# Res contains 1 null values
# PSCH contains 1 null values
# PSCD contains 1 null values
# PSCA contains 1 null values

# %% [markdown]
# Após uma investigação, descobriu-se que os valores nulos correspondem a uma partida da última rodada do campeonato Brasileiro do ano de 2016, entre Chapecoense e Atlético-MG, no dia 11/12/2016. A inexistência dos valores deve-se ao fato de que a partida não aconteceu, e ambas as equipes sofreram um [WO duplo](https://www.uol.com.br/esporte/futebol/campeonatos/brasileiro/serie-a/ultimas-noticias/2016/12/11/chapecoense-x-atletico-mg.htm).

# %%
for attribute in numerical_df:
    values = df[attribute].dropna()
    Q1 = values.quantile(0.25)
    Q3 = values.quantile(0.75)
    AIQ = Q3 - Q1
    lower_bound = Q1 - 1.5 * AIQ
    upper_bound = Q3 + 1.5 * AIQ

    outliers = values[(values < lower_bound) | (values > upper_bound)]

    print(f"Outliers in {attribute}:")
    print(outliers)
    print("-" * 40)
# Out:
# Outliers in HG:
# 3       4.0
# 24      4.0
# 42      4.0
# 52      5.0
# 74      4.0
#        ...
# 4976    6.0
# 4995    4.0
# 5002    4.0
# 5010    5.0
# 5018    4.0
# Name: HG, Length: 249, dtype: float64
# ----------------------------------------
# Outliers in AG:
# 618     5.0
# 671     5.0
# 1945    5.0
# 1948    6.0
# 2689    5.0
# 3099    5.0
# 3191    5.0
# 3198    5.0
# 3341    5.0
# 3381    5.0
# 3532    5.0
# 4217    5.0
# 4430    6.0
# 4520    5.0
# 4619    6.0
# 4624    5.0
# 4855    5.0
# Name: AG, dtype: float64
# ----------------------------------------
# Outliers in PSCH:
# 290     4.78
# 333     4.94
# 340     5.19
# 365     4.92
# 414     4.05
#         ...
# 4987    4.40
# 5006    6.68
# 5007    4.85
# 5025    4.11
# 5026    4.04
# Name: PSCH, Length: 252, dtype: float64
# ----------------------------------------
# Outliers in PSCD:
# 16      4.76
# 17      4.74
# 24      4.99
# 52      5.09
# 76      5.09
#         ...
# 4932    5.23
# 4933    5.01
# 4935    5.20
# 4976    6.58
# 4990    4.77
# Name: PSCD, Length: 322, dtype: float64
# ----------------------------------------
# Outliers in PSCA:
# 52      10.75
# 134     12.11
# 190     10.72
# 238     11.05
# 247     11.09
#         ...
# 4851    10.42
# 4881    14.61
# 4929    10.86
# 4932    15.70
# 4976    15.69
# Name: PSCA, Length: 208, dtype: float64
# ----------------------------------------
# Outliers in MaxCH:
# 290     4.84
# 333     5.09
# 340     5.60
# 365     5.40
# 450     4.45
#         ...
# 4987    4.41
# 5006    7.19
# 5007    5.08
# 5025    4.18
# 5026    4.35
# Name: MaxCH, Length: 263, dtype: float64
# ----------------------------------------
# Outliers in MaxCD:
# 24      5.04
# 52      5.50
# 76      5.09
# 80      4.90
# 90      5.40
#         ...
# 4931    5.00
# 4932    5.60
# 4933    5.01
# 4935    5.30
# 4976    6.60
# Name: MaxCD, Length: 312, dtype: float64
# ----------------------------------------
# Outliers in MaxCA:
# 52      11.04
# 134     12.17
# 190     11.00
# 213     10.50
# 238     12.00
#         ...
# 4881    15.00
# 4901    11.00
# 4929    11.00
# 4932    17.00
# 4976    15.69
# Name: MaxCA, Length: 226, dtype: float64
# ----------------------------------------
# Outliers in AvgCH:
# 290     4.18
# 333     4.40
# 340     4.98
# 365     4.66
# 450     3.89
#         ...
# 4981    8.45
# 4987    4.13
# 5006    6.42
# 5007    4.67
# 5026    3.93
# Name: AvgCH, Length: 239, dtype: float64
# ----------------------------------------
# Outliers in AvgCD:
# 52      4.54
# 99      4.57
# 134     4.53
# 146     4.48
# 190     4.60
#         ...
# 4935    5.02
# 4952    4.52
# 4976    6.39
# 4990    4.60
# 5014    4.54
# Name: AvgCD, Length: 322, dtype: float64
# ----------------------------------------
# Outliers in AvgCA:
# 99       8.98
# 134      9.43
# 238      9.54
# 293      9.75
# 297      9.99
#         ...
# 4858     9.13
# 4881    13.80
# 4929     9.80
# 4932    13.76
# 4976    14.52
# Name: AvgCA, Length: 186, dtype: float64
# ----------------------------------------
# Outliers in W_H:
# 355     22
# 375     22
# 704     21
# 723     23
# 744     23
# 1112    22
# 1134    23
# 1472    22
# 1492    23
# 1511    24
# 1873    21
# 1886    22
# 1896    21
# 2262    21
# 2651    21
# 2657    22
# 2954    21
# 2975    23
# 2980    24
# 3005    25
# 3029    27
# 3038    21
# 3748    22
# 3766    23
# 3780    25
# 3787    21
# 4149    21
# 4167    22
# 4910    21
# 4932    22
# 4939    22
# Name: W_H, dtype: int64
# ----------------------------------------
# Outliers in D_H:
# 707     15
# 722     15
# 741     16
# 3009    15
# 3033    15
# 3359    15
# 3369    16
# 3394    17
# 3405    17
# 3701    15
# 3718    15
# 3736    15
# 3741    15
# 3762    16
# 3765    15
# 3773    16
# 3783    16
# 3785    15
# 3786    16
# 4111    15
# 4140    16
# 4160    15
# 4174    16
# Name: D_H, dtype: int64
# ----------------------------------------
# Outliers in L_H:
# 340     21
# 372     21
# 689     21
# 708     23
# 728     25
# 751     28
# 1132    22
# 1855    21
# 1863    21
# 1878    22
# 1880    23
# 1888    22
# 2625    21
# 2658    23
# 2996    21
# 3012    23
# 3030    24
# 3031    21
# 3034    21
# 3777    22
# 3789    23
# 4161    21
# 4166    21
# 4505    21
# 4525    21
# 4535    22
# 4544    23
# 4552    23
# 4925    21
# Name: L_H, dtype: int64
# ----------------------------------------
# Outliers in GF_H:
# 723     72
# 744     75
# 1511    70
# 2980    68
# 3005    73
# 3029    80
# 3787    69
# Name: GF_H, dtype: int64
# ----------------------------------------
# Outliers in GA_H:
# 372     66
# 708     67
# 728     70
# 751     79
# 4493    66
# 4496    66
# 4505    67
# 4525    71
# 4535    69
# 4544    78
# 4552    71
# Name: GA_H, dtype: int64
# ----------------------------------------
# Outliers in GD_H:
# 234     22
# 240     25
# 250     24
# 256     22
# 274    -21
#         ..
# 4910    29
# 4925   -29
# 4927    21
# 4932    29
# 4939    28
# Name: GD_H, Length: 309, dtype: int64
# ----------------------------------------
# Outliers in W_A:
# 335     21
# 344     21
# 369     22
# 716     22
# 731     23
# 750     23
# 1109    21
# 1123    23
# 1464    21
# 1489    23
# 1505    24
# 1868    21
# 1871    21
# 1884    21
# 1899    23
# 2251    21
# 2277    21
# 2643    21
# 2947    21
# 2968    22
# 2984    24
# 3014    26
# 3020    21
# 3038    28
# 3418    21
# 3738    21
# 3758    23
# 3774    24
# 3778    21
# 3791    21
# 3795    26
# 4158    22
# 4178    23
# 4926    21
# 4927    21
# Name: W_A, dtype: int64
# ----------------------------------------
# Outliers in D_A:
# 714     15
# 734     16
# 751     17
# 2654    15
# 2991    15
# 3019    15
# 3027    15
# 3350    15
# 3362    15
# 3381    17
# 3414    17
# 3718    15
# 3721    15
# 3733    15
# 3743    15
# 3751    15
# 3755    15
# 3771    16
# 3775    15
# 3776    16
# 3790    15
# 3797    17
# 3798    16
# 4125    16
# 4134    16
# 4150    15
# 4154    16
# 4161    16
# 4177    15
# Name: D_A, dtype: int64
# ----------------------------------------
# Outliers in L_A:
# 692     22
# 719     24
# 733     26
# 746     27
# 1872    22
# 1896    23
# 1897    22
# 2648    22
# 3004    22
# 3029    23
# 3793    24
# 4536    22
# 4547    22
# 4550    23
# Name: L_A, dtype: int64
# ----------------------------------------
# Outliers in GF_A:
# 716     69
# 731     74
# 750     76
# 1505    70
# 2984    72
# 3014    77
# 3038    86
# 3418    67
# 3778    68
# 3791    69
# Name: GF_A, dtype: int64
# ----------------------------------------
# Outliers in GA_A:
# 374     69
# 719     68
# 733     71
# 746     77
# 4496    67
# 4514    69
# 4522    67
# 4536    74
# 4547    70
# 4550    80
# Name: GA_A, dtype: int64
# ----------------------------------------
# Outliers in GD_A:
# 223     22
# 231     23
# 244     23
# 259     22
# 262     21
#         ..
# 4914   -29
# 4915    22
# 4926    27
# 4927    28
# 4931   -27
# Name: GD_A, Length: 314, dtype: int64
# ----------------------------------------

# %% [markdown]
# ## e) Correlação dos atributos numéricos

# %%
temp_df = df.copy()

temp_df["Res"] = temp_df["Res"].map({"H": 1, "D": 0, "A": -1})
temp_df = temp_df.drop(["Season", "Home", "Away"], axis=1)

correlations = temp_df.corr(method='pearson')
correlations
# Out:
#              HG        AG       Res      PSCH      PSCD      PSCA     MaxCH  \
# AG     0.057014 -0.020311  0.111228
# Res   -0.057026  0.033891 -0.130582
# PSCH   0.159533 -0.134299  0.421536
# PSCD   0.005323  0.238703 -0.332209
# PSCA  -0.141979  0.182758 -0.465196
# MaxCH  0.160052 -0.127937  0.413417
# MaxCD -0.005192  0.232626 -0.338831
# MaxCA -0.139836  0.182708 -0.462226
# AvgCH  0.163225 -0.132649  0.424712
# AvgCD  0.000097  0.236441 -0.336627
# AvgCA -0.141691  0.186340 -0.470078
# W_H    0.739920  0.752410 -0.002854
# D_H    0.756883  0.774323 -0.009560
# L_H    0.745589  0.746407  0.013885
# GF_H   0.800679  0.813678 -0.002352
# GA_H   0.817269  0.822069  0.009662
# GD_H  -0.010188  0.001758 -0.017221
# W_A    0.940833  0.601369  0.502495
# D_A    0.718144  0.733091 -0.006793
# L_A    0.572669  0.927533 -0.493876
# GF_A   1.000000  0.757075  0.366187
# GA_A   0.757075  1.000000 -0.330717
# GD_A   0.366187 -0.330717  1.000000

# %%
weak_correlations = {}
for index_row, row in correlations.iterrows():
    for index_col in row.keys():
        if -0.2 < row[index_col] < 0.2:

            if index_row not in weak_correlations:
                weak_correlations[index_row] = []
            
            correlation = {index_col: row[index_col]}
            weak_correlations[index_row].append(correlation)


strong_correlations = {}
for index_row, row in correlations.iterrows():
    for index_col in row.keys():
        if (0.8 < row[index_col] < 1.0) or (-1.0 < row[index_col] < -0.8):

            if index_row not in strong_correlations:
                strong_correlations[index_row] = []
            
            correlation = {index_col: row[index_col]}
            strong_correlations[index_row].append(correlation)

print(weak_correlations)
print("")
print(strong_correlations)
# Out:
# {'HG': [{'AG': 0.023708379402106284}, {'W_H': 0.09899594526541668}, {'D_H': 0.0034735975734188325}, {'L_H': -0.0717409658943333}, {'GF_H': 0.07504136645523886}, {'GA_H': -0.03921189913969469}, {'GD_H': 0.1645999510563084}, {'W_A': -0.048978057900321316}, {'D_A': 0.0024766372238386857}, {'L_A': 0.07604011730110498}, {'GF_A': -0.0225933569077061}, {'GA_A': 0.06137528879581306}, {'GD_A': -0.12000952703271331}], 'AG': [{'HG': 0.023708379402106284}, {'PSCH': 0.1968007024437803}, {'PSCD': -0.07078105745844433}, {'PSCA': -0.16672101502335093}, {'MaxCH': 0.18724759061172855}, {'MaxCD': -0.07575109114549168}, {'MaxCA': -0.1619652847360456}, {'AvgCH': 0.1945981259369459}, {'AvgCD': -0.07434162148491684}, {'AvgCA': -0.1676608426687317}, {'W_H': -0.03736229996227165}, {'D_H': -0.009882867613561146}, {'L_H': 0.03633063703406214}, {'GF_H': -0.01960490350897105}, {'GA_H': 0.03360218677576135}, {'GD_H': -0.07639142465051708}, {'W_A': 0.06036092389898849}, {'D_A': -0.021635777442152847}, {'L_A': -0.050388387138069764}, {'GF_A': 0.057014287521653405}, {'GA_A': -0.020310852735343988}, {'GD_A': 0.11122789391626955}], 'Res': [{'PSCD': 0.17578651093587153}, {'MaxCD': 0.17988417986835217}, {'AvgCD': 0.17876563687196084}, {'W_H': 0.08114056431813019}, {'D_H': 0.003360475946295814}, {'L_H': -0.08353979471509648}, {'GF_H': 0.05361307758441703}, {'GA_H': -0.057710850521596545}, {'GD_H': 
# {'PSCH': [{'MaxCH': 0.9867918277468534}, {'AvgCH': 0.9954087813896336}], 'PSCD': [{'PSCA': 0.8516940629834754}, {'MaxCD': 0.9863526454697393}, {'MaxCA': 0.8594304970821774}, {'AvgCD': 0.986714910603758}, {'AvgCA': 0.8509180984965474}], 'PSCA': [{'PSCD': 0.8516940629834754}, {'MaxCD': 0.8576623749996207}, {'MaxCA': 0.9881069309016328}, {'AvgCD': 0.860007154867647}, {'AvgCA': 0.9918865573789956}], 'MaxCH': [{'PSCH': 0.9867918277468534}, {'AvgCH': 0.9937880414385774}], 'MaxCD': [{'PSCD': 0.9863526454697393}, {'PSCA': 0.8576623749996207}, {'MaxCA': 0.8683022801515733}, {'AvgCD': 0.987995180108293}, {'AvgCA': 0.8586818353004319}], 'MaxCA': [{'PSCD': 0.8594304970821774}, {'PSCA': 0.9881069309016328}, {'MaxCD': 0.8683022801515733}, {'AvgCD': 0.8699908743755289}, {'AvgCA': 0.9911226960421883}], 'AvgCH': [{'PSCH': 0.9954087813896336}, {'MaxCH': 0.9937880414385774}], 'AvgCD': [{'PSCD': 0.986714910603758}, {'PSCA': 0.860007154867647}, {'MaxCD': 0.987995180108293}, {'MaxCA': 0.8699908743755289}, {'AvgCA': 0.8657544382299688}], 'AvgCA': [{'PSCD': 0.8509180984965474}, {'PSCA': 0.9918865573789956}, {'MaxCD': 0.8586818353004319}, {'MaxCA': 0.9911226960421883}, {'AvgCD': 0.8657544382299688}], 'W_H': [{'GF_H': 0.9408350491199405}], 'L_H': [{'GA_H': 0.9266294238015672}], 'GF_H': [{'W_H': 0.9408350491199405}, {'GF_A': 0.8006786970577182}, {'GA_A': 0.8136778856567103}], 'GA_H': [{'L_H': 0.9266294238015672}, {'GF_A': 0.8172692350347545}, {'GA_A': 0.822068651511641}], 'W_A': [{'GF_A': 0.9408328193977537}], 'L_A': [{'GA_A': 0.9275325646960821}], 'GF_A': [{'GF_H': 0.8006786970577182}, {'GA_H': 0.8172692350347545}, {'W_A': 0.9408328193977537}], 'GA_A': [{'GF_H': 0.8136778856567103}, {'GA_H': 0.822068651511641}, {'L_A': 0.9275325646960821}]}

# %% [markdown]
# # 2 - Limpeza e transformação dos dados

# %% [markdown]
# ## a) Removendo valores nulos
# O dado de index 1891 corresponde à partida entre Chapecoense e Atlético-MG (Galo) que não ocorreu, como já foi explicado na letra D da parte 1. Por isso tal partida será removida do conjunto de dados

# %%
df = df.drop(1891)
check_null_itens(df) # if no print is made, then there is no null values

# %% [markdown]
# ## b) Suavização de ruídos

# %%
numerical_columns = list(set(df.columns.to_list())  - set(categorical_data))

for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    AIQ = Q3 - Q1
    upper_bound = Q3 + 1.5 * AIQ

    df[col] = df[col].astype(float)
    bounds, _ = pd.cut(df[col], 10, retbins=True)

    for index, row in df.iterrows():
        if row[col] > upper_bound:
            mean = (bounds[index].left + bounds[index].right) / 2.0
            df.loc[index, col] = mean

# %% [markdown]
# ## c) Resolvendo inconsistênicas
# Não há mais inconsistências nos dados, uma vez que a partida que apresentava já foi removida

# %% [markdown]
# ## d) Transformando atributos categóricos nominais em vetores numéricos

# %%
df = pd.get_dummies(df, columns=["Res"], prefix="Res", dtype=int, drop_first=True) # Transformando em on-hot-encoded

df = df.drop(["Season"], axis=1) # É um dado numérico, porém que não representa uma informação muito útil, uma vez que as estatísticas da temporada já estão incorporadas nas últimas colunas da tabela

df = df.drop(["Home", "Away"], axis=1) # Dados numéricos que não revelam grandes informações no momento

# %% [markdown]
# # e) Transformação de atributos categóricos ordinais
# Não há atributos categóricos ordinais nos dados

# %% [markdown]
# # f) Normalização de valores numéricos.

# %%
# min-max normalization
df[numerical_columns] = (df[numerical_columns] - df[numerical_columns].min()) / (df[numerical_columns].max() - df[numerical_columns].min())

df
# Out:
#             HG        AG      PSCH      PSCD      PSCA     MaxCH     MaxCD  \
# 0     0.150376  0.175439  0.042486  0.143097  0.151804  0.025269  0.132246
# 1     0.150376  0.175439  0.110970  0.092146  0.056649  0.065624  0.084253
# 2     0.300752  0.175439  0.032974  0.162610  0.206231  0.021875  0.151442
# 3     0.578947  0.350877  0.089410  0.087810  0.074051  0.052801  0.081054
# 4     0.000000  0.175439  0.055802  0.107323  0.120703  0.032812  0.095985
# ...        ...       ...       ...       ...       ...       ...       ...
# 5034  0.000000  0.350877  0.073557  0.065044  0.095155  0.044881  0.054391
# 5035  0.150376  0.175439  0.095751  0.058540  0.071829  0.059213  0.056524
# 5036  0.000000  0.175439  0.075460  0.060708  0.094785  0.046013  0.056524
# 5037  0.000000  0.350877  0.077362  0.066128  0.088861  0.048275  0.057591
# 5038  0.150376  0.000000  0.023462  0.203805  0.264731  0.014332  0.235696
#
#          MaxCA     AvgCH     AvgCD     AvgCA       W_H       D_H       L_H  \
# 0     0.155263  0.034062  0.125404  0.155225  0.000000  0.000000  0.000000
# 1     0.078947  0.083507  0.091203  0.059192  0.000000  0.000000  0.000000
# 2     0.211111  0.028568  0.146938  0.185856  0.000000  0.000000  0.000000
# 3     0.092105  0.070322  0.095003  0.069955  0.000000  0.000000  0.000000
# 4     0.128947  0.045050  0.103870  0.113418  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 5034  0.114035  0.063729  0.067135  0.101000  0.272904  0.061920  0.037594
# 5035  0.092105  0.081859  0.068402  0.075750  0.000000  0.123839  0.263158
# 5036  0.108480  0.063729  0.069669  0.099758  0.077973  0.185759  0.150376
# 5037  0.103801  0.065927  0.074736  0.094377  0.077973  0.247678  0.112782
# 5038  0.293567  0.019229  0.233074  0.289339  0.194932  0.123839  0.075188
#
#           GF_H      GA_H      GD_H       W_A       D_A       L_A      GF_A  \
# 0     0.000000  0.000000  0.575968  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.575968  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.575968  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.575968  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.575968  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 5034  0.144737  0.053298  0.645482  0.187970  0.185759  0.038986  0.208078
# 5035  0.052632  0.213191  0.456802  0.075188  0.247678  0.116959  0.134639
# 5036  0.131579  0.173218  0.546177  0.037594  0.123839  0.233918  0.085679
# 5037  0.131579  0.106596  0.595829  0.187970  0.123839  0.077973  0.159119
# 5038  0.144737  0.106596  0.605760  0.075188  0.123839  0.194932  0.097919
#
#           GA_A      GD_A  Res_D  Res_H
# 0     0.000000  0.540802      1      0
# 1     0.000000  0.540802      1      0
# 2     0.000000  0.540802      0      1
# 3     0.000000  0.540802      0      1
# 4     0.000000  0.540802      0      0
# ...        ...       ...    ...    ...
# 5034  0.052632  0.666345      0      0
# 5035  0.171053  0.521487      1      0
# 5036  0.144737  0.502173      0      0
# 5037  0.092105  0.598745      0      0
# 5038  0.276316  0.415258      0      1
#
# [5038 rows x 25 columns]
